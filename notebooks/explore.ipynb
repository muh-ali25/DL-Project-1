# %%
from PIL import Image
import os
import random
import matplotlib.pyplot as plt

# %%
os.chdir("../")

# %%
os.getcwd()
# Out:
# 'd:\\Course\\DL\\DL-Project-1'

# %%
image_files = []
for root, dirs, files in os.walk("data/processed/train"):
    for file in files:
        image_files.append(os.path.join(root, file))

# %%
image_file_select = random.sample(image_files,20)

# %%
image_file_select
# Out:
# ['data/processed/train\\chapati\\chapati108.jpg',
#  'data/processed/train\\paratha\\paratha76.jpg',
#  'data/processed/train\\fried_rice\\friedrice66.jpg',
#  'data/processed/train\\haleem\\haleem62.jpg',
#  'data/processed/train\\chai\\chai32.jpg',
#  'data/processed/train\\chai\\chai97.jpg',
#  'data/processed/train\\french_fries\\frenchfries95.jpg',
#  'data/processed/train\\bbq\\bbq70.jpg',
#  'data/processed/train\\chai\\chai22.jpg',
#  'data/processed/train\\omelette\\omelette43.jpg',
#  'data/processed/train\\bbq\\bbq99.jpg',
#  'data/processed/train\\biryani\\biryani2.jpg',
#  'data/processed/train\\french_fries\\frenchfries48.jpg',
#  'data/processed/train\\french_fries\\frenchfries14.jpg',
#  'data/processed/train\\bbq\\bbq66.jpg',
#  'data/processed/train\\butter_chicken\\butterchicken74.jpg',
#  'data/processed/train\\fried_rice\\friedrice58.jpg',
#  'data/processed/train\\butter_chicken\\butterchicken62.jpg',
#  'data/processed/train\\omelette\\omelette11.jpg',
#  'data/processed/train\\bbq\\bbq111.jpg']

# %%
fig, axes = plt.subplots(ncols=2,nrows=10, sharex=True, sharey=True)

for i, ax in enumerate(axes.flat):
    ax.imshow(Image.open(image_file_select[i]))
    ax.axis('off')
    ax.set_title(os.path.basename(image_file_select[i]))
plt.show()

# %%
import torch

# %%
x = torch.randn(4,4)

# %%
x
# Out:
# tensor([[-0.2547, -1.4167, -1.7343, -1.0878],
#         [ 0.3723, -0.2716,  0.1981,  0.1367],
#         [ 0.9911,  0.1449,  1.1718, -0.3592],
#         [ 1.5979, -0.6480,  1.0583,  1.0195]])

# %%
y = x.view(-1,8)

# %%
x.shape
# Out:
# torch.Size([4, 4])

# %%
y
# Out:
# tensor([[-0.2547, -1.4167, -1.7343, -1.0878,  0.3723, -0.2716,  0.1981,  0.1367],
#         [ 0.9911,  0.1449,  1.1718, -0.3592,  1.5979, -0.6480,  1.0583,  1.0195]])

# %%
y.shape
# Out:
# torch.Size([2, 8])
